# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/home/jyang4/repos/DCLO/data/GB1_AllPredictions.csv")

# %%
data[abs(data['Triad-FixedBb-dG']) < 5]
# Out:
#       Variants   Fitness Combo  esm_msa1_t12_100M_UR50S-Naive-ColumnUnmasked  \
# 1298      VDPP  0.002447  VDPP                                    -26.244790
# 9321      IDPP  0.001413  IDPP                                    -30.636210
# 19757     VAPP  0.004421  VAPP                                    -33.845023
# 20095     VCPP  0.010287  VCPP                                    -37.768956
# 20437     VEPP  0.000000  VEPP                                    -31.956256
# 20777     VFPP  0.002852  VFPP                                    -38.283176
# 21462     VHPP  0.005594  VHPP                                    -33.141798
# 21797     VIPP  0.000606  VIPP                                    -38.685884
# 22142     VKPP  0.001868  VKPP                                    -37.811780
# 22492     VLPP  0.001908  VLPP                                    -38.561402
# 23183     VNPP  0.000639  VNPP                                    -32.838350
# ...

# %%
plt.hist(data['Triad-FixedBb-dG'])
# Out:
# (array([2.0000e+01, 0.0000e+00, 2.1800e+02, 8.9300e+02, 5.6000e+01,
#         6.4330e+03, 1.4158e+04, 5.9000e+02, 6.4019e+04, 6.2974e+04]),
#  array([-110.22216 ,  -82.505152,  -54.788144,  -27.071136,    0.645872,
#           28.36288 ,   56.079888,   83.796896,  111.513904,  139.230912,
#          166.94792 ]),
#  <BarContainer object of 10 artists>)

# %%
from itertools import product

options1 = ['A', 'C', 'G']
options2 = ['T', 'C', 'C']
options3 = ['T', 'C', 'C']
options4 = ['T', 'C', 'C']
all = []
for x in map(''.join, product(*zip(options1, options2, options3, options4))):
    all.append(x)
print(len(all))
# Out:
# 64
